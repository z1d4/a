# %% [markdown]
# 9-a POS tagging and chunking of user define text

# %%
import nltk 
from nltk import tokenize
nltk.download('punkt')
from nltk import tag
from nltk import chunk
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
para="Hello  My name is Nidhi Parikh.Today we'll be learning NLTK"
sents= tokenize.sent_tokenize(para)
print("\nsentences tokenization\n=======================\n",sents)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# sentences tokenization
# ...
#  ["Hello  My name is Nidhi Parikh.Today we'll be learning NLTK"]
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
#word tokenization
print("\nsentences tokenization\n=======================\n")
for index in range(len(sents)):
  words=tokenize.word_tokenize(sents[index])
  print(words)
# Out:
# sentences tokenization
# ...
#
# ['Hello', 'My', 'name', 'is', 'Nidhi', 'Parikh.Today', 'we', "'ll", 'be', 'learning', 'NLTK']

# %% [markdown]
# pos tagging

# %%
tagged_words = []
for index in range(len(sents)):
  tagged_words.append(tag.pos_tag(words))
  print("\nPOS Tagging\===============\n",tagged_words)
# Out:
# POS Tagging\===============
#  [[('Hello', 'NNP'), ('My', 'NNP'), ('name', 'NN'), ('is', 'VBZ'), ('Nidhi', 'NNP'), ('Parikh.Today', 'NNP'), ('we', 'PRP'), ("'ll", 'MD'), ('be', 'VB'), ('learning', 'VBG'), ('NLTK', 'NNP')]]

# %% [markdown]
# chunking

# %%
tree= []
for index in range(len(sents)):
  tree.append(chunk.ne_chunk(tagged_words[index]))
  print("\nchunking\====================\n")
  print(tree)
# Out:
# chunking\====================
#
# [Tree('S', [Tree('PERSON', [('Hello', 'NNP')]), ('My', 'NNP'), ('name', 'NN'), ('is', 'VBZ'), Tree('PERSON', [('Nidhi', 'NNP')]), ('Parikh.Today', 'NNP'), ('we', 'PRP'), ("'ll", 'MD'), ('be', 'VB'), ('learning', 'VBG'), Tree('ORGANIZATION', [('NLTK', 'NNP')])])]

# %% [markdown]
# 9-b Named Entity Recognition using user defined text

# %%
pip install -U Spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-27 15:42:19.140180: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-27 15:42:20.511004: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
import spacy
nlp=spacy.load("en_core_web_sm")
text=("This is a mistake. Here, we’ll refer to some time-honored typesetting conventions, with an emphasis on readability,and offer guidance on adapting them effectively for devices and screens. We’ll see that the ability to embed fonts with @font-face is not by itself a solution to all of our typographic challenges.")
doc=nlp(text)
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
#Analyse syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])
# Out:
# Noun phrases: ['This', 'a mistake', 'we', 'some time-honored typesetting conventions', 'an emphasis', 'readability', 'guidance', 'them', 'devices', 'screens', 'We', 'the ability', 'fonts', '@font-face', 'itself', 'a solution', 'all', 'our typographic challenges']
# verbs: ['refer', 'honor', 'typeset', 'offer', 'adapt', 'see', 'embed']

# %% [markdown]
# #9-c Named Entity Recognition eith diagram using NLTK corpus treebank

# %%
#on thony
import nltk
nltk.download('treebank')
from nltk.corpus import treebank_chunk
treebank_chunk.tagged_sents()[0]
treebank_chunk.chunked_sents()[0]
treebank_chunk.chunked_sents()[0].draw()
# Out:
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-9-6eca2a032af9> in <module>
#       5 treebank_chunk.tagged_sents()[0]
#       6 treebank_chunk.chunked_sents()[0]
# ----> 7 treebank_chunk.chunked_sents()[0].draw()
#
# /usr/local/lib/python3.9/dist-packages/nltk/tree/tree.py in draw(self)
#     759         from nltk.draw.tree import draw_trees
#     760
# --> 761         draw_trees(self)
#     762
#     763     def pretty_print(self, sentence=None, highlight=(), stream=None, **kwargs):
#
# /usr/local/lib/python3.9/dist-packages/nltk/draw/tree.py in draw_trees(*trees)
#    1006     :rtype: None
#    1007     """
# -> 1008     TreeView(*trees).mainloop()
#    1009     return
#    1010
#
# ...
