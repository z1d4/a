# %% [markdown]
# Define grammar using nltk analyse the sentence using the same

# %% [markdown]
# prac-10-a

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#on thonny
import nltk 
from nltk import tokenize
grammar1=nltk.CFG.fromstring("""
S ->VP
VP ->VP NP
NP ->Det NP
Det ->'that'
NP -> Singular Noun
NP ->'flight'
VP ->'Book'
""")
sentence="Book that flight"
for index in range(len(sentence)):
  all_tokens= tokenize.word_tokenize(sentence)
print(all_tokens)
parser= nltk.ChartParser(grammar1)
for tree in parser.parse(all_tokens):
 print(tree)
 tree.draw()
# Out:
# ['Book', 'that', 'flight']
# (S (VP (VP Book) (NP (Det that) (NP flight))))
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-12-f404fc8e1970> in <module>
#      17 for tree in parser.parse(all_tokens):
#      18  print(tree)
# ---> 19  tree.draw()
#
# /usr/local/lib/python3.8/dist-packages/nltk/tree/tree.py in draw(self)
#     760         from nltk.draw.tree import draw_trees
#     761
# --> 762         draw_trees(self)
#     763
#     764     def pretty_print(self, sentence=None, highlight=(), stream=None, **kwargs):
#
# /usr/local/lib/python3.8/dist-packages/nltk/draw/tree.py in draw_trees(*trees)
#    1006     :rtype: None
#    1007     """
# -> 1008     TreeView(*trees).mainloop()
#    1009     return
#    1010
#
# /usr/local/lib/python3.8/dist-packages/nltk/draw/tree.py in __init__(self, *trees)
#     857         self._trees = trees
#     858
# --> 859         self._top = Tk()
#     860         self._top.title("NLTK")
#     861         self._top.bind("<Control-x>", self.destroy)
#
# /usr/lib/python3.8/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2268                 baseName = baseName + ext
#    2269         interactive = 0
# -> 2270         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2271         if useTk:
#    2272             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %% [markdown]
# prac-10-b Study Porter stemmer with an example

# %%
import nltk
from nltk.stem import PorterStemmer
word_stemmer = PorterStemmer()
print(word_stemmer.stem('writing'))
# Out:
# write

# %% [markdown]
# prac-10-c Study Porter stemmer with an example

# %%
import nltk
from nltk.stem import RegexpStemmer
Reg_stemmer = RegexpStemmer('ing$|e$|able$|',min=4)
print(Reg_stemmer.stem('writing'))
# Out:
# writ
