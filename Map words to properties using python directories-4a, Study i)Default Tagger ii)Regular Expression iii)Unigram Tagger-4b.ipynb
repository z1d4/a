# %%
#DefaultTagger
#Regular expression tagger
#unigramTagger

# %%
#4-a
pos={}

# %%
pos
# Out:
# {}

# %%
pos['colorless']='AJD'
pos['ideas']='N'
pos['sleep']='V'
pos['furiously']='ADV'

# %%
pos
# Out:
# {'colorless': 'AJD', 'ideas': 'N', 'sleep': 'V', 'furiously': 'ADV'}

# %%
pos['ideas']
# Out:
# 'N'

# %%
pos['colorless']
# Out:
# 'AJD'

# %%
list(pos)
# Out:
# ['colorless', 'ideas', 'sleep', 'furiously']

# %%
sorted(pos)
# Out:
# ['colorless', 'furiously', 'ideas', 'sleep']

# %%
[w for w in pos if w.endswith('s')]
# Out:
# ['colorless', 'ideas']

# %%
for word in sorted(pos):
  print(word+":",pos[word])
# Out:
# colorless: AJD
# furiously: ADV
# ideas: N
# sleep: V

# %%
pos.keys()
# Out:
# dict_keys(['colorless', 'ideas', 'sleep', 'furiously'])

# %%
pos.values()
# Out:
# dict_values(['AJD', 'N', 'V', 'ADV'])

# %%
pos.items()
# Out:
# dict_items([('colorless', 'AJD'), ('ideas', 'N'), ('sleep', 'V'), ('furiously', 'ADV')])

# %%
pos['sleep']=['N','V']

# %%
pos.items()
# Out:
# dict_items([('colorless', 'AJD'), ('ideas', 'N'), ('sleep', ['N', 'V']), ('furiously', 'ADV')])

# %%
os={'colorless':'ADJ','ideas':'N"','sleep':'V','furiously':'ADV'}
pos=dict(colorless='ADJ',ideas='N"',sleep='V',furiously='ADV')

# %%
pos
# Out:
# {'colorless': 'ADJ', 'ideas': 'N"', 'sleep': 'V', 'furiously': 'ADV'}

# %%
#default tagger-4-b
import nltk
nltk.download('brown')
from nltk.corpus import brown
tags=[tag for (word,tag) in brown.tagged_words(categories='news')]
nltk.FreqDist(tags).max()
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# 'NN'

# %%
nltk.download('punkt')
raw='I do not like green eggs and ham, I do not like them Sam I am!'
tokens=nltk.word_tokenize(raw)
default_tagger= nltk.DefaultTagger('NN')
default_tagger.tag(tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [('I', 'NN'),
#  ('do', 'NN'),
#  ('not', 'NN'),
#  ('like', 'NN'),
#  ('green', 'NN'),
#  ('eggs', 'NN'),
#  ('and', 'NN'),
#  ('ham', 'NN'),
#  (',', 'NN'),
#  ('I', 'NN'),
#  ('do', 'NN'),
#  ('not', 'NN'),
#  ('like', 'NN'),
#  ('them', 'NN'),
#  ('Sam', 'NN'),
#  ('I', 'NN'),
#  ('am', 'NN'),
#  ('!', 'NN')]

# %%
import nltk
from nltk.corpus import brown

brown_tagged_sents = brown.tagged_sents()
default_tagger = nltk.DefaultTagger('NN')
accuracy = default_tagger.evaluate(brown_tagged_sents)
print("Accuracy:", accuracy)
# Out:
# <ipython-input-21-e16f194573e6>:6: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   accuracy = default_tagger.evaluate(brown_tagged_sents)
# Accuracy: 0.13130472824476916

# %%
default_tagger.evaluate(brown_tagged_sents)
# Out:
# <ipython-input-22-87a1170c976d>:1: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   default_tagger.evaluate(brown_tagged_sents)
# 0.13130472824476916

# %%
#Regular expression tagger
from nltk.stem import regexp
patterns=[
    (r'.*ing$','VBG'),#gerunds
    (r'.*ed$','VBD'), #simple past
    (r'.*es$','VBZ'),#3rd singular present
    (r'.*ould$','MD'),
    (r'.*\'s$','NN$'),
    (r'.*s$','NNS'),
    (r'^-?[0-9]+(.[0-9]+)?$','CD'),
    (r'.*','NN')
]
regexp_tagger=nltk.RegexpTagger(patterns)
brown_sents=brown.sents()
regexp_tagger.tag(brown_sents[3])
# Out:
# [('``', 'NN'),
#  ('Only', 'NN'),
#  ('a', 'NN'),
#  ('relative', 'NN'),
#  ('handful', 'NN'),
#  ('of', 'NN'),
#  ('such', 'NN'),
#  ('reports', 'NNS'),
#  ('was', 'NNS'),
#  ('received', 'VBD'),
#  ("''", 'NN'),
#  (',', 'NN'),
#  ('the', 'NN'),
#  ('jury', 'NN'),
#  ('said', 'NN'),
#  (',', 'NN'),
#  ('``', 'NN'),
#  ('considering', 'VBG'),
#  ('the', 'NN'),
#  ('widespread', 'NN'),
#  ('interest', 'NN'),
#  ('in', 'NN'),
#  ('the', 'NN'),
#  ('election', 'NN'),
#  (',', 'NN'),
#  ('the', 'NN'),
#  ('number', 'NN'),
#  ('of', 'NN'),
#  ('voters', 'NNS'),
#  ('and', 'NN'),
#  ('the', 'NN'),
#  ('size', 'NN'),
#  ('of', 'NN'),
#  ('this', 'NNS'),
#  ('city', 'NN'),
#  ("''", 'NN'),
#  ('.', 'NN')]

# %%
from nltk.tokenize.casual import regex
brown_tagged_sents=nltk.corpus.brown.tagged_sents()
regexp_tagger.evaluate(brown_tagged_sents)
# Out:
# <ipython-input-24-7176ab9ea6e5>:3: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   regexp_tagger.evaluate(brown_tagged_sents)
# 0.19537768086586887

# %%
#unigram tagger
import nltk
nltk.download('brown')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.corpus import brown
tags=[tag for (word,tag) in brown.tagged_words(categories='news')]

# %%
brown_sents=brown.sents(categories='news')
brown_tagged_sents=nltk.corpus.brown.tagged_sents()

# %%
unigram_tagger=nltk.UnigramTagger(brown_tagged_sents)

# %%
unigram_tagger.tag(brown_sents[2007])
# Out:
# [('Various', 'JJ'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('apartments', 'NNS'),
#  ('are', 'BER'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('terrace', 'NN'),
#  ('type', 'NN'),
#  (',', ','),
#  ('being', 'BEG'),
#  ('on', 'IN'),
#  ('the', 'AT'),
#  ('ground', 'NN'),
#  ('floor', 'NN'),
#  ('so', 'QL'),
#  ('that', 'CS'),
#  ('entrance', 'NN'),
#  ('is', 'BEZ'),
#  ('direct', 'JJ'),
#  ('.', '.')]

# %%
unigram_tagger.evaluate(brown_tagged_sents)
# Out:
# <ipython-input-30-2be150522e1a>:1: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   unigram_tagger.evaluate(brown_tagged_sents)
# 0.9245482228606466
